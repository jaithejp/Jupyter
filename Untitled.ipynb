# %%
import pandas as pd
import time 
import sys
import numpy as np 

import matplotlib.pyplot as plt

# employee_names = pd.Series(["Amy White", "Jack Stewart", "Richard Lauderdale", "Sara Johnson"])

# Print the Series
# print(employee_names)

# data = [10, 20, 30, 40, 50]
# s = pd.Series(data)

employee_names = ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']

print(pd.type(employee_names))

# print(s)


# data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
#         'Age': [25, 30, 35, 28],
#         'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']}

# df = pd.DataFrame(data)
# print(df[1:3])
# print(df.loc[1])
# print(df[['Name', 'Age']])

# a = {'Student':['David', 'Samuel', 'Terry', 'Evan'],
#      'Age':['27', '24', '22', '32'],
#      'Country':['UK', 'Canada', 'China', 'USA'],
#      'Course':['Python','Data Structures','Machine Learning','Web Development'],
#      'Marks':['85','72','89','76']}
# df1 = pd.DataFrame(a)

# value = df1.iloc[0,1]
# value = df1.loc[0, 'Age']

# value
# value1 = df1.set_index('Name')

# df1.head()

# df1.loc[0,'Marks']
# df1

# df1.iloc[0:3, 0:3]

# b = df1[['Marks']]
# b

# c = df1[['Country','Course']]
# c

# x = df1['Student']
# x

# loc[row_label, column_label]

# u = np.array([1, 0])
# u

# v = np.array([0, 1])
# v

# z = np.add(u, v)
# z

# def Plotvec1(u, z, v):
    
#     ax = plt.axes() # to generate the full window axes
#     ax.arrow(0, 0, *u, head_width=0.05, color='r', head_length=0.1)# Add an arrow to the  U Axes with arrow head width 0.05, color red and arrow head length 0.1
#     plt.text(*(u + 0.1), 'u')#Adds the text u to the Axes 
    
#     ax.arrow(0, 0, *v, head_width=0.05, color='b', head_length=0.1)# Add an arrow to the  v Axes with arrow head width 0.05, color red and arrow head length 0.1
#     plt.text(*(v + 0.1), 'v')#Adds the text v to the Axes 
    
#     ax.arrow(0, 0, *z, head_width=0.05, head_length=0.1)
#     plt.text(*(z + 0.1), 'z')#Adds the text z to the Axes 
#     plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
#     plt.xlim(-2, 2)#set the xlim to left(-2), right(2)

# Plotvec1(u, z, v)

# arr = np.array([1, 2, 3, -1]) 

# # Enter your code here
# arr + 5

# np.pi

# x = np.array([0, np.pi/2 , np.pi])
# y = np.sin(x)
# y

# x = np.linspace(0, 2*np.pi, num=100)
# x

# y = np.sin(x)
# y

# np.linspace(5, 4, num=6)

# plt.plot(x, y)

# np.linspace(-2, 2, num=10)


# Import the libraries

# import time 
# import sys
# import numpy as np 

# import matplotlib.pyplot as plt


# def Plotvec2(a,b):
#     ax = plt.axes()# to generate the full window axes
#     ax.arrow(0, 0, *a, head_width=0.05, color ='r', head_length=0.1)#Add an arrow to the  a Axes with arrow head width 0.05, color red and arrow head length 0.1
#     plt.text(*(a + 0.1), 'a')
#     ax.arrow(0, 0, *b, head_width=0.05, color ='b', head_length=0.1)#Add an arrow to the  b Axes with arrow head width 0.05, color blue and arrow head length 0.1
#     plt.text(*(b + 0.1), 'b')
#     plt.ylim(-2, 2)#set the ylim to bottom(-2), top(2)
#     plt.xlim(-2, 2)#set the xlim to left(-2), right(2)

# a = np.array([1, 0])
# a
# b = np.array([0, 1])
# b
# # Plotvec2(a, b)
# print("The dot product is", np.dot(a,b))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 18
#       8 # employee_names = pd.Series(["Amy White", "Jack Stewart", "Richard Lauderdale", "Sara Johnson"])
#       9
#      10 # Print the Series
#    (...)
#      13 # data = [10, 20, 30, 40, 50]
#      14 # s = pd.Series(data)
#      16 employee_names = ['Amy White', 'Jack Stewart', 'Richard Lauderdale', 'Sara Johnson']
# ---> 18 print(pd.type(employee_names))
#      20 # print(s)
#      21
#      22
#    (...)
#     134 # # Plotvec2(a, b)
#     135 # print("The dot product is", np.dot(a,b))
#
# AttributeError: module 'pandas' has no attribute 'type'
